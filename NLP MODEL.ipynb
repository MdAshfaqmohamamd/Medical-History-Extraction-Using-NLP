# %%
import sys,os
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install pillow
# !pip install pytesseract
import pytesseract
import matplotlib.pyplot as plt
import numpy as np
import cv2
import re
from PIL.PpmImagePlugin import PpmImageFile # used as type hint
from typing import Dict # used as type hint

# Setting required paths related to library functions
POPPLER_PATH = r"C:\Program Files\poppler-24.07.0\Library\bin"
TESSERACT_ENGINE_PATH = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
pytesseract.pytesseract.tesseract_cmd = TESSERACT_ENGINE_PATH
# Out:
# Requirement already satisfied: opencv-python in c:\users\admin\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\admin\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\anaconda3\lib\site-packages (from opencv-contrib-python) (1.24.3)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: pytesseract in c:\users\admin\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\lib\site-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pytesseract) (9.4.0)

# %%
image= r"C:\Users\Admin\Desktop\DATASET_mp2\Dataset\prescription_dataset\printed\PRS208C4021562.jpg"

# %%
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Original Prescription Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       3 plt.axis("off")
#       4 plt.title("Original Prescription Image")
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
import cv2
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
image_path =r"C:\Users\Admin\Desktop\DATASET_mp2\Dataset\prescription_dataset\printed\PRS208C4021562.jpg"  # Replace with your image path
image = cv2.imread(image_path)

# Display the original image
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Original Prescription Image")
plt.show()

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to preprocess the image
gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# Use Tesseract OCR to extract text
text = pytesseract.image_to_string(gray, lang="eng")

# Print extracted text
print("Extracted Text:")
print(text)
# Out:
# Extracted Text:
# tpifepeds pausoauos ou) 10) SAE
#
# 110 Apps 84 210
#
# aimevbss
#
# ‘WB ‘nc eb “ae ee a TA le aba lc
# dn-monos
#
# te tbl 8 EUS Otis "E
# Tis tl es"
# sl lve 20 hn"
#
# NPY
# 20H
# Ea aig +
# of ‘Gurtd wf
# Wa ae ee
# parry
# wre rapuca mie oC -
# oud %070 50 NOTE 7 |
# ang ee se = ues
# inawunto vaso vives |
# va seg nie | et owe
# ost peed \ Aust
# ral rar ane, Bk 8 1d © suumen
# soc wp eau actor | supe +
# OW S$ aaTv av buyon +
# ea aoe
# auerduie9 Je
#
# ee
# ovzeOoe
#
# npn mn pees 12 OA TE
#
# pry BOF vee
# woe we
#
# swose 308
#
# woos, (afajgagatonaisaent
# verpycemeung enna zerie® con'aa a
#
# ye
#
# ‘at ob ¥20z:E00
# LpvesaboeorZA PL
#
# jou 2
#
# ae
#
# gto: OUT GCE
#
# qvu1dsOH AOaTI00 T
#
# ——

# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Function to preprocess image using Adaptive Thresholding
def preprocess_image(img: Image.Image) -> np.ndarray:
    gray = cv2.cvtColor(np.array(img), cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    resized = cv2.resize(gray, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)  # Upscale image
    processed_image = cv2.adaptiveThreshold(
        resized, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 63, 12
    )  # Apply adaptive thresholding
    return processed_image

# Load the image
image_path = r"C:\Users\Admin\Desktop\DATASET_mp2\Dataset\prescription_dataset\printed\PRS208C4021562.jpg"  # Replace with your image path
original_image = Image.open(image_path)

# Rotate the image vertically (180 degrees)
rotated_image = original_image.rotate(180)

# Display the rotated image
plt.figure(figsize=(8, 6))
plt.imshow(rotated_image)
plt.axis("off")
plt.title("Rotated Prescription Image")
plt.show()

# Preprocess the rotated image
processed_image = preprocess_image(rotated_image)

# Display the processed image
plt.figure(figsize=(8, 6))
plt.imshow(processed_image, cmap="gray")
plt.axis("off")
plt.title("Preprocessed Image for OCR")
plt.show()

# Use Tesseract OCR to extract text
text = pytesseract.image_to_string(processed_image, lang="eng")

# Print extracted text
print("Extracted Text:")
print(text)
# Out:
# Extracted Text:
# A MEDICAL COLLEGE HOSPITAL
#
# é IBN SIN ann
# NT DEPARTMENT TICKET
#
# ‘Ticket: y240301 399111
# Print Time + 3003/2024 10.18
#
# Patent: ANOWARA BEGUM
# pate ; 2008/2024 10.18 Age : 40% 0M GO Gander: Female signature : Md, Zahirul Islam
# Conguttant ; Prot. Dt. Sajed Abdul Khateque MBBS(OMC),FCPSIEY®) Room: 607
#
# ks SOO 88 outside Ticket
#
# Description of diseases ¢ Clinical diagnosis +
# ‘Treatment +
# 9p: 30032407
# Chief Complaint
# w Eyeache Rx,
# a Bching 4, TAB, ALCET 5 MG
# © Redness o+0+9f0 Meet 10 50 fra
# © Difficulty in Vision
# ‘ 2 LOTEREX G EVE DROP
# © Wetering een amant afm
# SOF RAE aba
# History Y ehma SRK TAL a fra
# 3. LOTEFLAM 0.50% OINTMENT
# Bon Examinations 7 ae 3 ieeR ote IITA TH
# © VAR-6/6,NS e glass, 4, PATALON DS 0.20% DROP
# ” yatta aE FOU GNY a7
#
# VAL-S/6.NS @ glass
#
# Diagnosis
# * Allergic
# Conjunctivitis
# J
#
# Eye Glass
#
# 50Dsph
# Remark: eflective/Plastic/Bifocal
# Advices
# 1, qeratt CATH ATTA STSTRAY
# 2a ara core “ifs Fea)
# 3. PaaS cored Bo SPI FA
#
# Follow-up
# ene OT, AT HA, TH ATTA, ATT. AS, CATE,
#
# Signature
#
# Note: The validity of this Ucket bs 7 days for the concemed specialist

# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Function to preprocess image using Adaptive Thresholding
def preprocess_image(img: Image.Image) -> np.ndarray:
    gray = cv2.cvtColor(np.array(img), cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    resized = cv2.resize(gray, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)  # Upscale image
    processed_image = cv2.adaptiveThreshold(
        resized, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 63, 12
    )  # Apply adaptive thresholding
    return processed_image

# Load the image
image_path = r"C:\Users\Admin\Desktop\DATASET_mp2\Dataset\prescription_dataset\printed\PRS208C4021562c.jpg"  # Replace with your image path
original_image = Image.open(image_path)

# Display the original image
plt.figure(figsize=(8, 6))
plt.imshow(original_image)
plt.axis("off")
plt.title("Original Prescription Image")
plt.show()

# Preprocess the image
processed_image = preprocess_image(original_image)

# Display the processed image
plt.figure(figsize=(8, 6))
plt.imshow(processed_image, cmap="gray")
plt.axis("off")
plt.title("Preprocessed Image for OCR")
plt.show()

# Use Tesseract OCR to extract text
text = pytesseract.image_to_string(processed_image, lang="eng")

# Print extracted text
print("Extracted Text:")
print(text)
# Out:
# Extracted Text:
# L
#
# é SB, Kallang Dish Aaimiistration OLD H-998555. Customnet
# \E4 OUT PATIENT DEPARTMENT T' ICKET
#
# JBN SINA
# newer
#
# Received with thanks Ticket ; y240301 999114
# Patignt : ANOWARA BEGUM Print Tims: 3or032024 10.16
# Dave : 907032024 10.18 Age :40Y 0M GO Gender: Femate Signatuse : Md. Zabirul Islam
# Consultant = prof. Dr. Saied ‘Abdul Khateque MMaBs(OMC),FCPSIEve) Room: 607
#
# 500. as outside Ticket
#
# Clinical diagnosis
# ‘Treatment >
#
# Description of diseases +
#
# 1, 30032407
# Chief Complaint
# RY
# 4, TAB. ALCET 5 MG
#
# © Eyeache
# © ching
# = Redness o+043t atawta 18 30 fin
# «Difficulty in Vision
# . ‘ 2. LOTEREX G EYE DROP
# ‘Wetering sams Bou ont age
# History SQA RA 4
# ® Be Asthma youre afr
# 3, LOTEFLAM 0.50% OINTMENT
# AL ontxaminations 28 ae pice emer TTA RT
# © VAR-G/E.N5 e glass, 4, PATALON DS 0.20% DROP
# _ y at Ra Ter aTT aa
#
# ; VAL-G/6.NS € glass
#
# Diagnosis
# «Allergic
# Conjunctivitis:
# WJ
#
# Eye Glass
#
# Add: (+} 1.50Dsph
#
# Remark: Antireflective/Plastic/Bifocal
# Advices
#
# 4, STI ACF AAMT AIRTRA|
#
# 2, area mea coTCA A TAR |
#
# 3, Rae cored Gt TAG Fa
#
# Follow-up
# corny a emo ATC ITAA, HEA A SHAT, ATTS = MEH, CTH, A
#
# oe
#
# Signature
#
# Note: The validity of thes ticket is 7 days for the concemed specialist

# %%
# !pip install spacy 
import re
import spacy
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download NLTK stopwords if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load Spacy's English model (replace with a medical-specific model if needed)
nlp = spacy.load("en_core_web_sm")  # Use "en_core_sci_md" for SciSpacy medical model

# Function to clean text (remove special characters, extra spaces, and convert to lowercase)
def clean_text(text: str) -> str:
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W+', ' ', text)  # Remove special characters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Function for NLP processing (Tokenization, Stopword Removal, NER)
def process_text(text: str):
    # Cleaning text
    cleaned_text = clean_text(text)
    
    # Tokenization
    tokens = word_tokenize(cleaned_text)
    
    # Stopword Removal
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Named Entity Recognition (NER) using Spacy
    doc = nlp(cleaned_text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]

    return {
        "cleaned_text": cleaned_text,
        "tokens": filtered_tokens,
        "entities": entities
    }



# Perform NLP processing
nlp_results = process_text(text)

# Display NLP results
print("\nCleaned Text:\n", nlp_results["cleaned_text"])
print("\nTokens:\n", nlp_results["tokens"])
print("\nNamed Entities:\n", nlp_results["entities"])
